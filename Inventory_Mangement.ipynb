# %%
record={
        2001:{"MobileName":"OnePlus","Memory":"128GB","Ram":"6GB","Battery":"4500mH","Color":"Black","Price":35000,"Qty":100},
        2002:{"MobileName":"OnePlus","Memory":"128GB","Ram":"8GB","Battery":"45000mH","Color":"Blue","Price":45000,"Qty":100},
        2003:{"MobileName":"OnePlus","Memory":"256GB","Ram":"12GB","Battery":"5000mH","Color":"Black","Price":56000,"Qty":100},
        2004:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"8GB","Battery":"3000mH","Color":"Blue","Price":16000,"Qty":100},
        2005:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"12GB","Battery":"4500mH","Color":"Black","Price":17000,"Qty":100},
        2006:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"12GB","Battery":"4500mH","Color":"Blue","Price":17000,"Qty":100},
        2007:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"6GB","Battery":"4500mH","Color":"Black","Price":18000,"Qty":100},
        2008:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"6GB","Battery":"4500mH","Color":"Blue","Price":18000,"Qty":100},
        2009:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Black","Price":20000,"Qty":100},
        2010:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Blue","Price":20000,"Qty":100},
        2011:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Black","Price":20500,"Qty":100},
        2012:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Blue","Price":20500,"Qty":100},
        2013:{"MobileName":"Vivo","Memory":"128GB","Ram":"6GB","Battery":"3000mH","Color":"White","Price":15000,"Qty":100},
        2014:{"MobileName":"Vivo","Memory":"128GB","Ram":"6GB","Battery":"3000mH","Color":"Gold","Price":15500,"Qty":100},
        2015:{"MobileName":"Vivo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"White","Price":17000,"Qty":100},
        2016:{"MobileName":"Vivo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Gold","Price":17500,"Qty":100},
        2017:{"MobileName":"Mi","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"White","Price":16000,"Qty":100},
        2018:{"MobileName":"Mi","Memory":"128GB","Ram":"8GB","Battery":"4500mH","Color":"Black","Price":14500,"Qty":100},
        2019:{"MobileName":"Mi","Memory":"128GB","Ram":"8GB","Battery":"4500mH","Color":"Gold","Price":15500,"Qty":100},
        2020:{"MobileName":"Mi","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Black","Price":20000,"Qty":100},
        2021:{"MobileName":"Mi","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Gold","Price":20000,"Qty":100},
        2022:{"MobileName":"Oppo","Memory":"128GB","Ram":"6GB","Battery":"4500mH","Color":"Gold","Price":17000,"Qty":100},
        2023:{"MobileName":"Oppo","Memory":"128GB","Ram":"6GB","Battery":"4500mH","Color":"White","Price":17000,"Qty":100},
        2024:{"MobileName":"Oppo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Gold","Price":19000,"Qty":100},
        2025:{"MobileName":"Oppo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"White","Price":19000,"Qty":100},
        2026:{"MobileName":"Oppo","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Gold","Price":21000,"Qty":100},
        2027:{"MobileName":"Oppo","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"White","Price":21000,"Qty":100},
        2028:{"MobileName":"Apple","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Blue","Price":90000,"Qty":100},
        2029:{"MobileName":"Apple","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Black","Price":90000,"Qty":100},
        2030:{"MobileName":"Motorola","Memory":"128GB","Ram":"6GB","Battery":"4500mH","Color":"Black","Price":15000,"Qty":100},
}

# %%
import json
js=json.dumps(record)
pd=open('record.json','w')
pd.write(js)
pd.close()

# %%
mobilename=input("mobilename: ")
memory=input("memory: ")
ram=input("ram: ")
battery=input("battery: ")
color=input("color: ")
price=int(input("price: "))
qty=int(input("No of items want to add into Inventory: "))
for j in record.keys():
    if record[j]["MobileName"]==mobilename and record[j]["Memory"]==memory and record[j]["Ram"]==ram and record[j]["Battery"]==battery and record[j]["Color"]==color:
        record[j]["Qty"]=record[j]["Qty"]+qty
        break
else:
    record[2000+len(record)+1]={"MobileName":mobilename,"Memory":memory,"Ram":ram,"Battery":battery,"Color":color,"Price":price,"Qty":qty}
import json
js=json.dumps(record)
pd=open('record.json','w')
pd.write(js)
pd.close()
# Out:
# mobilename: Nokia
# memory: 256GB
# ram: 6GB
# battery: 4500mH
# color: White
# price: 24999
# No of items want to add into Inventory: 89

# %%
record
# Out:
# {2001: {'MobileName': 'OnePlus',
#   'Memory': '128GB',
#   'Ram': '6GB',
#   'Battery': '4500mH',
#   'Color': 'Black',
#   'Price': 35000,
#   'Qty': 100},
#  2002: {'MobileName': 'OnePlus',
#   'Memory': '128GB',
#   'Ram': '8GB',
#   'Battery': '45000mH',
#   'Color': 'Blue',
#   'Price': 45000,
#   'Qty': 100},
#  2003: {'MobileName': 'OnePlus',
#   'Memory': '256GB',
#   'Ram': '12GB',
#   'Battery': '5000mH',
#   'Color': 'Black',
#   'Price': 56000,
#   'Qty': 100},
#  2004: {'MobileName': 'SamsungM30',
#   'Memory': '128GB',
#   'Ram': '8GB',
#   'Battery': '3000mH',
#   'Color': 'Blue',
#   'Price': 16000,
#   'Qty': 100},
#  2005: {'MobileName': 'SamsungM30',
#   'Memory': '128GB',
#   'Ram': '12GB',
#   'Battery': '4500mH',
#   'Color': 'Black',
#   'Price': 17000,
#   'Qty': 100},
#  2006: {'MobileName': 'SamsungM30',
#   'Memory': '128GB',
#   'Ram': '12GB',
#   'Battery': '4500mH',
#   'Color': 'Blue',
#   'Price': 17000,
#   'Qty': 100},
# ...

# %% [markdown]
# # **Purchase**

# %%
N=int(input("Enter the Quantity: "))
TotalPrice=0
mobilename=input("mobilename: ")
memory=input("memory: ")
ram=input("ram: ")
battery=input("battery: ")
color=input("color: ")
for j in record.keys():
    if record[j]["MobileName"]==mobilename and record[j]["Memory"]==memory and record[j]["Ram"]==ram and record[j]["Battery"]==battery and record[j]["Color"]==color:
        if record[j]["Qty"]>=N:
            print(N*record[j]["Price"])
            print("Product-Id: "+str(j))
            record[j]["Qty"]=record[j]["Qty"]-N
        else:
            print(str(record[j]["Qty"])+" Mobiles are Available")
            print(record[j]["Price"]*record[j]["Qty"])
            print("Product-Id: "+str(j))
            record[j]["Qty"]=0
        break
else:
    print("Model Not Found")
# Out:
# Enter the Quantity: 28
# mobilename: Apple
# memory: 256GB
# ram: 12GB
# battery: 4500mH
# color: Blue
# 2520000
# Product-Id: 2028

# %%
record
# Out:
# {2001: {'MobileName': 'OnePlus',
#   'Memory': '128GB',
#   'Ram': '6GB',
#   'Battery': '4500mH',
#   'Color': 'Black',
#   'Price': 35000,
#   'Qty': 100},
#  2002: {'MobileName': 'OnePlus',
#   'Memory': '128GB',
#   'Ram': '8GB',
#   'Battery': '45000mH',
#   'Color': 'Blue',
#   'Price': 45000,
#   'Qty': 100},
#  2003: {'MobileName': 'OnePlus',
#   'Memory': '256GB',
#   'Ram': '12GB',
#   'Battery': '5000mH',
#   'Color': 'Black',
#   'Price': 56000,
#   'Qty': 100},
#  2004: {'MobileName': 'SamsungM30',
#   'Memory': '128GB',
#   'Ram': '8GB',
#   'Battery': '3000mH',
#   'Color': 'Blue',
#   'Price': 16000,
#   'Qty': 100},
#  2005: {'MobileName': 'SamsungM30',
#   'Memory': '128GB',
#   'Ram': '12GB',
#   'Battery': '4500mH',
#   'Color': 'Black',
#   'Price': 17000,
#   'Qty': 100},
#  2006: {'MobileName': 'SamsungM30',
#   'Memory': '128GB',
#   'Ram': '12GB',
#   'Battery': '4500mH',
#   'Color': 'Blue',
#   'Price': 17000,
#   'Qty': 100},
# ...

# %%
js=json.dumps(record)
pd=open('record.json','w')
pd.write(js)
pd.close()

# %%
sales={
       1:{"Product_id":2001,"Quantity":4,"Amount":60000},
       2:{"Product_id":2002,"Quantity":1,"Amount":15000},
       3:{"Product_id":2003,"Quantity":3,"Amount":48000},
       4:{"Product_id":2004,"Quantity":2,"Amount":32000},
       5:{"Product_id":2005,"Quantity":5,"Amount":85000},
       6:{"Product_id":2006,"Quantity":5,"Amount":85000},
       7:{"Product_id":2007,"Quantity":5,"Amount":90000},
       8:{"Product_id":2008,"Quantity":5,"Amount":90000},
       9:{"Product_id":2009,"Quantity":5,"Amount":100000},
       10:{"Product_id":2010,"Quantity":5,"Amount":10000},
       }

js=json.dumps(sales)
pd=open('sales.json','w')
pd.write(js)
pd.close()

# %%
product_id=int(input("product_id: "))
quantity=int(input("quantity: "))
sales[len(sales)+1]={"Product_id":product_id,"Quantity":quantity,"Amount":record[product_id]["Price"]*quantity}
import json
js=json.dumps(sales)
pd=open('sales.json','w')
pd.write(js)
pd.close()
# Out:
# product_id: 2005
# quantity: 10

# %%
sales
# Out:
# {1: {'Product_id': 2001, 'Quantity': 4, 'Amount': 60000},
#  2: {'Product_id': 2002, 'Quantity': 1, 'Amount': 15000},
#  3: {'Product_id': 2003, 'Quantity': 3, 'Amount': 48000},
#  4: {'Product_id': 2004, 'Quantity': 2, 'Amount': 32000},
#  5: {'Product_id': 2005, 'Quantity': 5, 'Amount': 85000},
#  6: {'Product_id': 2006, 'Quantity': 5, 'Amount': 85000},
#  7: {'Product_id': 2007, 'Quantity': 5, 'Amount': 90000},
#  8: {'Product_id': 2008, 'Quantity': 5, 'Amount': 90000},
#  9: {'Product_id': 2009, 'Quantity': 5, 'Amount': 100000},
#  10: {'Product_id': 2010, 'Quantity': 5, 'Amount': 10000},
#  11: {'Product_id': 2005, 'Quantity': 10, 'Amount': 170000}}
